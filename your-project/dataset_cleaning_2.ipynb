# %% [markdown]
# # DATASET CLEANING

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## First Dataset: Immigrants by Nationality

# %%
# first we import the csv file as a dataset called i_by_age
nationality = pd.read_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/immigrants-by-nationality.csv')

# %%
# we check the datatypes
nationality.dtypes
# Out:
# Year                  int64
# District Code         int64
# District Name        object
# Neighborhood Code     int64
# Neighborhood Name    object
# Nationality          object
# Number                int64
# dtype: object

# %%
# and we check how is our dataset
nationality
# Out:
#        Year  District Code        District Name  Neighborhood Code  \
# 0      2017              1         Ciutat Vella                  1
# 1      2017              1         Ciutat Vella                  2
# 2      2017              1         Ciutat Vella                  3
# 3      2017              1         Ciutat Vella                  4
# 4      2017              2             Eixample                  5
# 5      2017              2             Eixample                  6
# 6      2017              2             Eixample                  7
# 7      2017              2             Eixample                  8
# 8      2017              2             Eixample                  9
# 9      2017              2             Eixample                 10
# 10     2017              3       Sants-Montjuïc                 11
# 11     2017              3       Sants-Montjuïc                 12
# 12     2017              3       Sants-Montjuïc                 13
# ...

# %%
# We will focus on immigrants by District and Nationality in Year 2017, so we will delete the columns District Code, Neighborhood Code, Neighborhoode Name

nationality_cleaned = nationality.loc[(nationality.Year == 2017),['Year', 'District Name','Nationality','Number']]
nationality_cleaned
# Out:
#        Year        District Name     Nationality  Number
# 0      2017         Ciutat Vella           Spain    1109
# 1      2017         Ciutat Vella           Spain     482
# 2      2017         Ciutat Vella           Spain     414
# 3      2017         Ciutat Vella           Spain     537
# 4      2017             Eixample           Spain     663
# 5      2017             Eixample           Spain    1181
# 6      2017             Eixample           Spain    1063
# 7      2017             Eixample           Spain    1177
# 8      2017             Eixample           Spain    1593
# 9      2017             Eixample           Spain     883
# 10     2017       Sants-Montjuïc           Spain     826
# 11     2017       Sants-Montjuïc           Spain      23
# 12     2017       Sants-Montjuïc           Spain     574
# 13     2017       Sants-Montjuïc           Spain     264
# 14     2017       Sants-Montjuïc           Spain     410
# ...

# %%
# As we have the dataset as we want, we can export to a new csv file. Altough we selected all 2017 rows and we could remove this column, we are keeping it as a note for future readings.

nationality.loc[(nationality.Year == 2017),['Year', 'District Name','Nationality','Number']].to_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/nationality_cleaned.csv')

# %% [markdown]
# ## Second Dataset: Gender by immigrants

# %%
# we import the csv file as a dataset called gender
gender = pd.read_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/immigrants-emigrants-by-sex.csv')

# %%
# we check the datatypes
gender.dtypes
# Out:
# Year                  int64
# District Code         int64
# District Name        object
# Neighborhood Code     int64
# Neighborhood Name    object
# Gender               object
# Immigrants            int64
# Emigrants             int64
# dtype: object

# %%
# and we check how is our dataset
gender
# Out:
#      Year  District Code        District Name  Neighborhood Code  \
# 0    2017              1         Ciutat Vella                  1
# 1    2017              1         Ciutat Vella                  2
# 2    2017              1         Ciutat Vella                  3
# 3    2017              1         Ciutat Vella                  4
# 4    2017              2             Eixample                  5
# 5    2017              2             Eixample                  6
# 6    2017              2             Eixample                  7
# 7    2017              2             Eixample                  8
# 8    2017              2             Eixample                  9
# 9    2017              2             Eixample                 10
# 10   2017              3       Sants-Montjuïc                 11
# 11   2017              3       Sants-Montjuïc                 12
# 12   2017              3       Sants-Montjuïc                 13
# ...

# %%
# We will focus on the population by District, Gender and Age in Year 2017, so we will delete the columns District Code, Neighborhood Code, Neighborhood Name and Emmigrants.

gender_cleaned = gender.loc[gender.Year == 2017, ['Year', 'District Name', 'Gender', 'Immigrants']]
gender_cleaned
# Out:
#      Year        District Name  Gender  Immigrants
# 0    2017         Ciutat Vella    Male        3063
# 1    2017         Ciutat Vella    Male        1499
# 2    2017         Ciutat Vella    Male         910
# 3    2017         Ciutat Vella    Male        1438
# 4    2017             Eixample    Male        1082
# 5    2017             Eixample    Male        1693
# 6    2017             Eixample    Male        1543
# 7    2017             Eixample    Male        1693
# 8    2017             Eixample    Male        1927
# 9    2017             Eixample    Male        1253
# 10   2017       Sants-Montjuïc    Male        1595
# 11   2017       Sants-Montjuïc    Male          17
# 12   2017       Sants-Montjuïc    Male         724
# 13   2017       Sants-Montjuïc    Male         351
# 14   2017       Sants-Montjuïc    Male         584
# 15   2017       Sants-Montjuïc    Male         471
# 16   2017       Sants-Montjuïc    Male         703
# ...

# %%
# As we have the dataset as we want, we can export to a new csv file. Altough we selected all 2017 rows and we could remove this column, we are keeping it as a note for future readings.

gender.loc[gender.Year == 2017, ['Year', 'District Name', 'Gender', 'Immigrants']].to_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/gender_cleaned.csv')
